# %% [markdown]
# ## Preparing the dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_tracks=pd.read_csv("C:\\Users\\admin\\Desktop\\final\\music.csv")

# %%
data_tracks.head()
# Out:
#    track_id  bit_rate  comments        composer         date_created  \
# 0       135    256000         1             NaN  2008-11-26 01:43:26
# 1       136    256000         1             NaN  2008-11-26 01:43:35
# 2       151    192000         0             NaN  2008-11-26 01:44:55
# 3       152    192000         0             NaN  2008-11-26 01:44:58
# 4       153    256000         0  Arc and Sender  2008-11-26 01:45:00
#
#          date_recorded  duration  favorites genre_top    genres  ...  \
# 0  2008-11-26 00:00:00       837          0      Rock  [45, 58]  ...
# 1  2008-11-26 00:00:00       509          0      Rock  [45, 58]  ...
# 2                  NaN       192          0      Rock      [25]  ...
# 3                  NaN       193          0      Rock      [25]  ...
# 4  2008-11-26 00:00:00       405          5      Rock      [26]  ...
#
#   information interest  language_code  \
# 0         NaN     2484             en
# 1         NaN     1948             en
# ...

# %%
json_data=pd.read_json("C:\\Users\\admin\\Desktop\\final\\echonest-metrics.json")

# %%
json_data
# Out:
#        track_id  acousticness  danceability    energy  instrumentalness  \
# 0             2      0.416675      0.675894  0.634476          0.010628
# 1             3      0.374408      0.528643  0.817461          0.001851
# 2             5      0.043567      0.745566  0.701470          0.000697
# 3            10      0.951670      0.658179  0.924525          0.965427
# 4           134      0.452217      0.513238  0.560410          0.019443
# ...         ...           ...           ...       ...               ...
# 13124    124857      0.007592      0.790364  0.719288          0.853114
# 13125    124862      0.041498      0.843077  0.536496          0.865151
# 13126    124863      0.000124      0.609686  0.895136          0.846624
# 13127    124864      0.327576      0.574426  0.548327          0.452867
# 13128    124911      0.993606      0.499339  0.050622          0.945677
#
#        liveness  speechiness    tempo   valence
# 0      0.177647     0.159310  165.922  0.576661
# ...

# %%
#joining these two tables

# %%
combined = pd.merge(json_data, data_tracks[["track_id", "genre_top"]], on="track_id")

# %%
combined.head()
# Out:
#    track_id  acousticness  danceability    energy  instrumentalness  liveness  \
# 0         2      0.416675      0.675894  0.634476          0.010628  0.177647
# 1         3      0.374408      0.528643  0.817461          0.001851  0.105880
# 2         5      0.043567      0.745566  0.701470          0.000697  0.373143
# 3       134      0.452217      0.513238  0.560410          0.019443  0.096567
# 4       153      0.988306      0.255661  0.979774          0.973006  0.121342
#
#    speechiness    tempo   valence genre_top
# 0     0.159310  165.922  0.576661   Hip-Hop
# 1     0.461818  126.957  0.269240   Hip-Hop
# 2     0.124595  100.260  0.621661   Hip-Hop
# 3     0.525519  114.290  0.894072   Hip-Hop
# 4     0.051740   90.241  0.034018      Rock

# %%
combined.describe()
# Out:
#             track_id  acousticness  danceability       energy  \
# count    4802.000000  4.802000e+03   4802.000000  4802.000000
# mean    30164.871720  4.870600e-01      0.436556     0.625126
# std     28592.013796  3.681396e-01      0.183502     0.244051
# min         2.000000  9.491000e-07      0.051307     0.000279
# 25%      7494.250000  8.351236e-02      0.296047     0.450757
# 50%     20723.500000  5.156888e-01      0.419447     0.648374
# 75%     44240.750000  8.555765e-01      0.565339     0.837016
# max    124722.000000  9.957965e-01      0.961871     0.999768
#
#        instrumentalness     liveness  speechiness        tempo      valence
# count       4802.000000  4802.000000  4802.000000  4802.000000  4802.000000
# mean           0.604096     0.187997     0.104877   126.687944     0.453413
# std            0.376487     0.150562     0.145934    34.002473     0.266632
# min            0.000000     0.025297     0.023234    29.093000     0.014392
# ...

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          4802 non-null   int64
#  1   acousticness      4802 non-null   float64
#  2   danceability      4802 non-null   float64
#  3   energy            4802 non-null   float64
#  4   instrumentalness  4802 non-null   float64
#  5   liveness          4802 non-null   float64
#  6   speechiness       4802 non-null   float64
#  7   tempo             4802 non-null   float64
#  8   valence           4802 non-null   float64
#  9   genre_top         4802 non-null   object
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB

# %% [markdown]
# ## Pairwise relationship

# %%
corr_metrics = combined.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_0202cc2e_dc40_11ea_b8a0_c6ed2617a83drow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0202cc2e_dc40_11ea_b8a0_c6ed2617a83drow0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0202cc2e_dc40_11ea_b8a0_c6ed2617a83drow0_col2 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_0202cc2e_dc40_11ea_b8a0_c6ed2617a83drow0_col3 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_0202cc2e_dc40_11ea_b8a0_c6ed2617a83drow0_col4 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_0202cc2e_dc40_11ea_b8a0_c6ed2617a83drow0_col5 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_0202cc2e_dc40_11ea_b8a0_c6ed2617a83drow0_col6 {
#             background-color:  #d1d2e6;
#             color:  #000000;
# ...

# %%
# define your features and labels

# %%
features = combined.drop(["genre_top","track_id"], axis=1)

# Define our labels
labels = combined["genre_top"]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)

# %%
pd.DataFrame(scaled_train_features).head(5)
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.191210  1.304420  0.038316 -1.576494 -0.068755  0.373034  1.153979
# 1 -0.306036  0.501886  0.788176 -1.599809 -0.545463  2.446155  0.007914
# 2 -1.204813  1.684139  0.312852 -1.602876  1.229828  0.135130 -0.777317
# 3 -0.094655  0.417927 -0.265203 -1.553079 -0.607326  2.882707 -0.364657
# 4  1.361706 -0.985896  1.453323  0.979975 -0.442757 -0.364157 -1.072003
#
#           7
# 0  0.462287
# 1 -0.690811
# 2  0.631077
# 3  1.652859
# 4 -1.573102

# %%
from sklearn.decomposition import PCA

#apply pca to your data
pca = PCA()
pca.fit(scaled_train_features)
variance = pca.explained_variance_ratio_

print(variance)
print("\n")
print("Number of components = {}".format(pca.n_components_))
# Out:
# [0.24297674 0.18044316 0.13650309 0.12994089 0.11056248 0.08302245
#  0.06923783 0.04731336]
#
#
# Number of components = 8

# %%
#plotting the variance
fig, ax = plt.subplots()
ax.bar(range(8),variance)
ax.set_xlabel('Principal component')
# Out:
# Text(0.5, 0, 'Principal component')

# %%
cum_exp_variance = np.cumsum(variance)
#plotting the com variance
fig, ax = plt.subplots()
ax.plot(range(8), cum_exp_variance)
ax.axhline(y=0.9, linestyle='--')
n_components = 6

# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components, random_state=10)
pca.fit(scaled_train_features)
pca_projection = pca.transform(scaled_train_features)

# %% [markdown]
# ## Training our models

# %% [markdown]
# """Decision Tree"""

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection, labels, random_state=10)

# %%
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=10, splitter='best')

# %%
pred_labels_tree = tree.predict(test_features)

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(test_labels, pred_labels_tree)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      Hip-Hop       0.60      0.60      0.60       235
#         Rock       0.90      0.90      0.90       966
#
#     accuracy                           0.84      1201
#    macro avg       0.75      0.75      0.75      1201
# weighted avg       0.84      0.84      0.84      1201

# %% [markdown]
# """Logistic regression"""

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)


report_log = classification_report(test_labels, pred_labels_logit)


print(report_log)
# Out:
#               precision    recall  f1-score   support
#
#      Hip-Hop       0.77      0.54      0.64       235
#         Rock       0.90      0.96      0.93       966
#
#     accuracy                           0.88      1201
#    macro avg       0.83      0.75      0.78      1201
# weighted avg       0.87      0.88      0.87      1201

# %%
# we have difference in the classificaion of hip hop and rock in the report.so we will have to balance the data

# %%
hop_only = combined.loc[combined["genre_top"] == "Hip-Hop"]
rock_only = combined.loc[combined["genre_top"] == "Rock"].sample(len(hop_only), random_state=12)

# concatenate the dataframes rock_only and hop_only
rock_hop_bal = pd.concat([rock_only, hop_only])

# doing pca on the features and labels again
features = rock_hop_bal.drop(['genre_top', 'track_id'], axis=1) 
labels = rock_hop_bal['genre_top']
pca_projection = pca.fit_transform(scaler.fit_transform(features))

# calculating our train and test again
train_features, test_features, train_labels, test_labels = train_test_split(pca_projection, labels, random_state=12)

# %%
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)
pred_labels_tree = tree.predict(test_features)

# %%
logg = LogisticRegression(random_state=10)
logg.fit(train_features, train_labels)
pred_labels_logg = logreg.predict(test_features)

# %%
print(classification_report(test_labels, pred_labels_tree))
print( classification_report(test_labels, pred_labels_logit))
# Out:
#               precision    recall  f1-score   support
#
#      Hip-Hop       0.76      0.77      0.76       223
#         Rock       0.77      0.77      0.77       232
#
#     accuracy                           0.77       455
#    macro avg       0.77      0.77      0.77       455
# weighted avg       0.77      0.77      0.77       455
#
#               precision    recall  f1-score   support
#
#      Hip-Hop       0.96      0.25      0.39       223
#         Rock       0.58      0.99      0.73       232
#
#     accuracy                           0.63       455
#    macro avg       0.77      0.62      0.56       455
# weighted avg       0.77      0.63      0.56       455

# %% [markdown]
# ## using cross validation

# %%
from sklearn.model_selection import KFold, cross_val_score

k = KFold(n_splits=11, random_state=12)

tree = DecisionTreeClassifier(random_state=12)
logreg = LogisticRegression(random_state=12)

# Train our models using KFold cv
tree_score = cross_val_score(tree, pca_projection, labels, cv=k)
logit_score = cross_val_score(logreg, pca_projection, labels, cv=k)

# Print the mean of each array of scores
print("Decision Tree:", np.mean(tree_score), "Logistic Regression:", np.mean(logit_score))
# Out:
# Decision Tree: 0.7340635268346112 Logistic Regression: 0.7747253476716783
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_split.py:292: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
